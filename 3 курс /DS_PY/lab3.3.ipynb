# %%
path = 'untitled1.txt'
surname_file = open(path, 'r')
surname_file.read()
# Out:
# 'Артемчук Богатко Буйко Гарбузов Гоцев Горбач Гром Данилов Иванчук Житько'

# %%
counter = 0
path = 'untitled1.txt'
surname_file = open(path, 'r')
for word in surname_file.read().split(' '):
    counter += 1
    print(str(counter) + " " + word)
# Out:
# 1 Артемчук
# 2 Богатко
# 3 Буйко
# 4 Гарбузов
# 5 Гоцев
# 6 Горбач
# 7 Гром
# 8 Данилов
# 9 Иванчук
# 10 Житько

# %%
path = 'untitled1.txt'
path1 = 'untitled2.txt'
path2 = 'untitled3.txt'
surname_file = open(path, 'r')
surname_file1 = open(path1, 'r')
surname_file2 = open(path2, 'w')
for word in surname_file.read().split(' '):
    surname_file2.write(word + " "+ surname_file1.readline())
surname_file2.close()

# %%
path3 = 'untitled3.txt'
surname_file3 = open(path3, 'r')
for word in surname_file3.readlines():
    words = word.split(' ')
    print(words[0], words[1][0:1])
# Out:
# Артемчук В
# Богатко В
# Буйко С
# Гарбузов Д
# Гоцев М
# Горбач В
# Гром Д
# Данилов Т
# Иванчук И
# Житько А

# %%
import math
print(math.log(15)/math.log(2))
# Out:
# 3.9068905956085187

# %%
import random
random.seed(5)
print(random.random())
random.seed(5)
print(random.random())
random.seed(5)
print(random.random())
random.seed(5)
print(random.random())
# Out:
# 0.6229016948897019
# 0.6229016948897019
# 0.6229016948897019
# 0.6229016948897019

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_2',
#  '_24',
#  '_25',
#  '_3',
#  '_4',
#  '_5',
#  '_6',
#  '_80',
#  '_81',
#  '_82',
#  '_83',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i53',
#  '_i54',
#  '_i55',
#  '_i56',
#  '_i57',
#  '_i58',
#  '_i59',
#  '_i6',
#  '_i60',
#  '_i61',
#  '_i62',
#  '_i63',
#  '_i64',
#  '_i65',
#  '_i66',
#  '_i67',
#  '_i68',
#  '_i69',
#  '_i7',
#  '_i70',
#  '_i71',
#  '_i72',
#  '_i73',
#  '_i74',
#  '_i75',
#  '_i76',
#  '_i77',
#  '_i78',
#  '_i79',
#  '_i8',
#  '_i80',
#  '_i81',
#  '_i82',
#  '_i83',
#  '_i84',
#  '_i85',
#  '_i86',
#  '_i87',
#  '_i88',
#  '_i89',
#  '_i9',
#  '_i90',
#  '_i91',
#  '_i92',
#  '_i93',
#  '_i94',
#  '_i95',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'counter',
#  'exit',
#  'get_ipython',
#  'math',
#  'path',
#  'path1',
#  'path2',
#  'path3',
#  'quit',
#  'random',
#  'surname_file',
#  'surname_file1',
#  'surname_file2',
#  'surname_file3',
#  'word',
#  'words']

# %%
import module3
module3.hello()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-57e1542765c7> in <module>()
# ----> 1 import module3
#       2 module3.hello()
#
# ~/module3.py in <module>()
#       3   {
#       4    "cell_type": "code",
# ----> 5    "execution_count": null,
#       6    "metadata": {},
#       7    "outputs": [],
#
# NameError: name 'null' is not defined
